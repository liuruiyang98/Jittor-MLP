# %%
import jittor as jt
from models_jittor import gMLPForImageClassification as gMLP_jt
from models_jittor import ResMLPForImageClassification as ResMLP_jt
from models_jittor import MLPMixerForImageClassification as MLPMixer_jt
from models_jittor import ViP as ViP_jt
from models_jittor import S2MLPv2 as S2MLPv2_jt

# %%
import torch
from models_pytorch import gMLPForImageClassification as gMLP_pt
from models_pytorch import ResMLPForImageClassification as ResMLP_pt
from models_pytorch import MLPMixerForImageClassification as MLPMixer_pt
from models_pytorch import ViP as ViP_pt
from models_pytorch import S2MLPv2 as S2MLPv2_pt 
import time

# %%
# model_jt = gMLP_jt(
#     image_size=224,
#     patch_size=16,
#     in_channels=3,
#     num_classes=1000,
#     d_model=256,
#     d_ffn=1536,
#     depth=30,
# )

# model_jt = ResMLP_jt(
#     in_channels = 3,
#     image_size = 224,
#     patch_size = 16,
#     d_model = 384,
#     depth = 12,
#     num_classes = 1000, 
#     expansion_factor = 4
# )

# model_jt = MLPMixer_jt(
#     image_size=(224,112),
#     patch_size=(16, 8),
#     in_channels=3,
#     num_classes=1000,
#     d_model=256,
#     depth=12,
# )

# model_jt = ViP_jt(
#     image_size=(224, 112),
#     patch_size=(16, 8),
#     in_channels=3,
#     num_classes=1000,
#     d_model=256,
#     depth=30,
#     segments = 16,
#     weighted = False
# )

model_jt = S2MLPv2_jt(
    in_channels = 3,
    image_size = (224,224),
    patch_size = [7],
    d_model = [384],
    depth = [18],
    num_classes = 1000, 
    expansion_factor = [3]
)

# %%
model_pt = gMLP_pt(
    image_size=(224,224),
    patch_size=16,
    in_channels=3,
    num_classes=1000,
    d_model=256,
    d_ffn=1536,
    depth=30
)

# model_pt = ResMLP_pt(
#     in_channels = 3,
#     image_size = (224,112),
#     patch_size = 16,
#     d_model = 384,
#     depth = 12,
#     num_classes = 1000, 
#     expansion_factor = 4
# )

# model_pt = MLPMixer_pt(
#     image_size=(224,112),
#     patch_size=16,
#     in_channels=3,
#     num_classes=1000,
#     d_model=256,
#     depth=12,
# )

# model_pt = ViP_pt(
#     image_size=(224, 112),
#     patch_size=(16, 8),
#     in_channels=3,
#     num_classes=1000,
#     d_model=256,
#     depth=30,
#     segments = 16,
#     weighted = False
# )

# model_pt = S2MLPv2_pt(
#     in_channels = 3,
#     image_size = (224,224),
#     patch_size = [(7,7), (2,2)],
#     d_model = [192, 384],
#     depth = [4, 14],
#     num_classes = 1000, 
#     expansion_factor = [3, 3]
# )

# %%
images = jt.randn(8, 3, 224, 224)

with jt.no_grad():
    output = model_jt(images)
print(output.shape)

# %%
images = torch.randn(8, 3, 224, 224)

with torch.no_grad():
    output = model_pt(images)
print(output.shape)
# Out:
# torch.Size([8, 1000])

# %%
from torchsummary import summary
summary(model_pt, (3, 224, 224), device="cpu")

# from torchstat import stat
# stat(model_pt, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 256, 14, 14]         196,864
#          LayerNorm-2             [-1, 196, 256]             512
#             Linear-3            [-1, 196, 3072]         789,504
#          LayerNorm-4            [-1, 196, 1536]           3,072
#             Conv1d-5            [-1, 196, 1536]          38,612
#  SpatialGatingUnit-6            [-1, 196, 1536]               0
#             Linear-7             [-1, 196, 256]         393,472
#          gMLPBlock-8             [-1, 196, 256]               0
#          LayerNorm-9             [-1, 196, 256]             512
#            Linear-10            [-1, 196, 3072]         789,504
#         LayerNorm-11            [-1, 196, 1536]           3,072
#            Conv1d-12            [-1, 196, 1536]          38,612
# SpatialGatingUnit-13            [-1, 196, 1536]               0
#            Linear-14             [-1, 196, 256]         393,472
#         gMLPBlock-15             [-1, 196, 256]               0
#         LayerNorm-16             [-1, 196, 256]             512
#            Linear-17            [-1, 196, 3072]         789,504
#         LayerNorm-18            [-1, 196, 1536]           3,072
#            Conv1d-19            [-1, 196, 1536]          38,612
# SpatialGatingUnit-20            [-1, 196, 1536]               0
#            Linear-21             [-1, 196, 256]         393,472
#         gMLPBlock-22             [-1, 196, 256]               0
#         LayerNorm-23             [-1, 196, 256]             512
#            Linear-24            [-1, 196, 3072]         789,504
#         LayerNorm-25            [-1, 196, 1536]           3,072
#            Conv1d-26            [-1, 196, 1536]          38,612
# SpatialGatingUnit-27            [-1, 196, 1536]               0
#            Linear-28             [-1, 196, 256]         393,472
#         gMLPBlock-29             [-1, 196, 256]               0
#         LayerNorm-30             [-1, 196, 256]             512
#            Linear-31            [-1, 196, 3072]         789,504
#         LayerNorm-32            [-1, 196, 1536]           3,072
#            Conv1d-33            [-1, 196, 1536]          38,612
# SpatialGatingUnit-34            [-1, 196, 1536]               0
#            Linear-35             [-1, 196, 256]         393,472
#         gMLPBlock-36             [-1, 196, 256]               0
#         LayerNorm-37             [-1, 196, 256]             512
#            Linear-38            [-1, 196, 3072]         789,504
#         LayerNorm-39            [-1, 196, 1536]           3,072
#            Conv1d-40            [-1, 196, 1536]          38,612
# SpatialGatingUnit-41            [-1, 196, 1536]               0
#            Linear-42             [-1, 196, 256]         393,472
#         gMLPBlock-43             [-1, 196, 256]               0
#         LayerNorm-44             [-1, 196, 256]             512
#            Linear-45            [-1, 196, 3072]         789,504
#         LayerNorm-46            [-1, 196, 1536]           3,072
#            Conv1d-47            [-1, 196, 1536]          38,612
# SpatialGatingUnit-48            [-1, 196, 1536]               0
#            Linear-49             [-1, 196, 256]         393,472
#         gMLPBlock-50             [-1, 196, 256]               0
#         LayerNorm-51             [-1, 196, 256]             512
#            Linear-52            [-1, 196, 3072]         789,504
#         LayerNorm-53            [-1, 196, 1536]           3,072
#            Conv1d-54            [-1, 196, 1536]          38,612
# SpatialGatingUnit-55            [-1, 196, 1536]               0
#            Linear-56             [-1, 196, 256]         393,472
#         gMLPBlock-57             [-1, 196, 256]               0
#         LayerNorm-58             [-1, 196, 256]             512
#            Linear-59            [-1, 196, 3072]         789,504
#         LayerNorm-60            [-1, 196, 1536]           3,072
#            Conv1d-61            [-1, 196, 1536]          38,612
# SpatialGatingUnit-62            [-1, 196, 1536]               0
#            Linear-63             [-1, 196, 256]         393,472
#         gMLPBlock-64             [-1, 196, 256]               0
#         LayerNorm-65             [-1, 196, 256]             512
#            Linear-66            [-1, 196, 3072]         789,504
#         LayerNorm-67            [-1, 196, 1536]           3,072
#            Conv1d-68            [-1, 196, 1536]          38,612
# SpatialGatingUnit-69            [-1, 196, 1536]               0
#            Linear-70             [-1, 196, 256]         393,472
#         gMLPBlock-71             [-1, 196, 256]               0
#         LayerNorm-72             [-1, 196, 256]             512
#            Linear-73            [-1, 196, 3072]         789,504
#         LayerNorm-74            [-1, 196, 1536]           3,072
#            Conv1d-75            [-1, 196, 1536]          38,612
# SpatialGatingUnit-76            [-1, 196, 1536]               0
#            Linear-77             [-1, 196, 256]         393,472
#         gMLPBlock-78             [-1, 196, 256]               0
#         LayerNorm-79             [-1, 196, 256]             512
#            Linear-80            [-1, 196, 3072]         789,504
#         LayerNorm-81            [-1, 196, 1536]           3,072
#            Conv1d-82            [-1, 196, 1536]          38,612
# SpatialGatingUnit-83            [-1, 196, 1536]               0
#            Linear-84             [-1, 196, 256]         393,472
#         gMLPBlock-85             [-1, 196, 256]               0
#         LayerNorm-86             [-1, 196, 256]             512
#            Linear-87            [-1, 196, 3072]         789,504
#         LayerNorm-88            [-1, 196, 1536]           3,072
#            Conv1d-89            [-1, 196, 1536]          38,612
# SpatialGatingUnit-90            [-1, 196, 1536]               0
#            Linear-91             [-1, 196, 256]         393,472
#         gMLPBlock-92             [-1, 196, 256]               0
#         LayerNorm-93             [-1, 196, 256]             512
#            Linear-94            [-1, 196, 3072]         789,504
#         LayerNorm-95            [-1, 196, 1536]           3,072
#            Conv1d-96            [-1, 196, 1536]          38,612
# SpatialGatingUnit-97            [-1, 196, 1536]               0
#            Linear-98             [-1, 196, 256]         393,472
#         gMLPBlock-99             [-1, 196, 256]               0
#        LayerNorm-100             [-1, 196, 256]             512
#           Linear-101            [-1, 196, 3072]         789,504
#        LayerNorm-102            [-1, 196, 1536]           3,072
#           Conv1d-103            [-1, 196, 1536]          38,612
# SpatialGatingUnit-104            [-1, 196, 1536]               0
#           Linear-105             [-1, 196, 256]         393,472
#        gMLPBlock-106             [-1, 196, 256]               0
#        LayerNorm-107             [-1, 196, 256]             512
#           Linear-108            [-1, 196, 3072]         789,504
#        LayerNorm-109            [-1, 196, 1536]           3,072
#           Conv1d-110            [-1, 196, 1536]          38,612
# SpatialGatingUnit-111            [-1, 196, 1536]               0
#           Linear-112             [-1, 196, 256]         393,472
#        gMLPBlock-113             [-1, 196, 256]               0
#        LayerNorm-114             [-1, 196, 256]             512
#           Linear-115            [-1, 196, 3072]         789,504
#        LayerNorm-116            [-1, 196, 1536]           3,072
#           Conv1d-117            [-1, 196, 1536]          38,612
# SpatialGatingUnit-118            [-1, 196, 1536]               0
#           Linear-119             [-1, 196, 256]         393,472
#        gMLPBlock-120             [-1, 196, 256]               0
#        LayerNorm-121             [-1, 196, 256]             512
#           Linear-122            [-1, 196, 3072]         789,504
#        LayerNorm-123            [-1, 196, 1536]           3,072
#           Conv1d-124            [-1, 196, 1536]          38,612
# SpatialGatingUnit-125            [-1, 196, 1536]               0
#           Linear-126             [-1, 196, 256]         393,472
#        gMLPBlock-127             [-1, 196, 256]               0
#        LayerNorm-128             [-1, 196, 256]             512
#           Linear-129            [-1, 196, 3072]         789,504
#        LayerNorm-130            [-1, 196, 1536]           3,072
#           Conv1d-131            [-1, 196, 1536]          38,612
# SpatialGatingUnit-132            [-1, 196, 1536]               0
#           Linear-133             [-1, 196, 256]         393,472
#        gMLPBlock-134             [-1, 196, 256]               0
#        LayerNorm-135             [-1, 196, 256]             512
#           Linear-136            [-1, 196, 3072]         789,504
#        LayerNorm-137            [-1, 196, 1536]           3,072
#           Conv1d-138            [-1, 196, 1536]          38,612
# SpatialGatingUnit-139            [-1, 196, 1536]               0
#           Linear-140             [-1, 196, 256]         393,472
#        gMLPBlock-141             [-1, 196, 256]               0
#        LayerNorm-142             [-1, 196, 256]             512
#           Linear-143            [-1, 196, 3072]         789,504
#        LayerNorm-144            [-1, 196, 1536]           3,072
#           Conv1d-145            [-1, 196, 1536]          38,612
# SpatialGatingUnit-146            [-1, 196, 1536]               0
#           Linear-147             [-1, 196, 256]         393,472
#        gMLPBlock-148             [-1, 196, 256]               0
#        LayerNorm-149             [-1, 196, 256]             512
#           Linear-150            [-1, 196, 3072]         789,504
#        LayerNorm-151            [-1, 196, 1536]           3,072
#           Conv1d-152            [-1, 196, 1536]          38,612
# SpatialGatingUnit-153            [-1, 196, 1536]               0
#           Linear-154             [-1, 196, 256]         393,472
#        gMLPBlock-155             [-1, 196, 256]               0
#        LayerNorm-156             [-1, 196, 256]             512
#           Linear-157            [-1, 196, 3072]         789,504
#        LayerNorm-158            [-1, 196, 1536]           3,072
#           Conv1d-159            [-1, 196, 1536]          38,612
# SpatialGatingUnit-160            [-1, 196, 1536]               0
#           Linear-161             [-1, 196, 256]         393,472
#        gMLPBlock-162             [-1, 196, 256]               0
#        LayerNorm-163             [-1, 196, 256]             512
#           Linear-164            [-1, 196, 3072]         789,504
#        LayerNorm-165            [-1, 196, 1536]           3,072
#           Conv1d-166            [-1, 196, 1536]          38,612
# SpatialGatingUnit-167            [-1, 196, 1536]               0
#           Linear-168             [-1, 196, 256]         393,472
#        gMLPBlock-169             [-1, 196, 256]               0
#        LayerNorm-170             [-1, 196, 256]             512
#           Linear-171            [-1, 196, 3072]         789,504
#        LayerNorm-172            [-1, 196, 1536]           3,072
#           Conv1d-173            [-1, 196, 1536]          38,612
# SpatialGatingUnit-174            [-1, 196, 1536]               0
#           Linear-175             [-1, 196, 256]         393,472
#        gMLPBlock-176             [-1, 196, 256]               0
#        LayerNorm-177             [-1, 196, 256]             512
#           Linear-178            [-1, 196, 3072]         789,504
#        LayerNorm-179            [-1, 196, 1536]           3,072
#           Conv1d-180            [-1, 196, 1536]          38,612
# SpatialGatingUnit-181            [-1, 196, 1536]               0
#           Linear-182             [-1, 196, 256]         393,472
#        gMLPBlock-183             [-1, 196, 256]               0
#        LayerNorm-184             [-1, 196, 256]             512
#           Linear-185            [-1, 196, 3072]         789,504
#        LayerNorm-186            [-1, 196, 1536]           3,072
#           Conv1d-187            [-1, 196, 1536]          38,612
# SpatialGatingUnit-188            [-1, 196, 1536]               0
#           Linear-189             [-1, 196, 256]         393,472
#        gMLPBlock-190             [-1, 196, 256]               0
#        LayerNorm-191             [-1, 196, 256]             512
#           Linear-192            [-1, 196, 3072]         789,504
#        LayerNorm-193            [-1, 196, 1536]           3,072
#           Conv1d-194            [-1, 196, 1536]          38,612
# SpatialGatingUnit-195            [-1, 196, 1536]               0
#           Linear-196             [-1, 196, 256]         393,472
#        gMLPBlock-197             [-1, 196, 256]               0
#        LayerNorm-198             [-1, 196, 256]             512
#           Linear-199            [-1, 196, 3072]         789,504
#        LayerNorm-200            [-1, 196, 1536]           3,072
#           Conv1d-201            [-1, 196, 1536]          38,612
# SpatialGatingUnit-202            [-1, 196, 1536]               0
#           Linear-203             [-1, 196, 256]         393,472
#        gMLPBlock-204             [-1, 196, 256]               0
#        LayerNorm-205             [-1, 196, 256]             512
#           Linear-206            [-1, 196, 3072]         789,504
#        LayerNorm-207            [-1, 196, 1536]           3,072
#           Conv1d-208            [-1, 196, 1536]          38,612
# SpatialGatingUnit-209            [-1, 196, 1536]               0
#           Linear-210             [-1, 196, 256]         393,472
#        gMLPBlock-211             [-1, 196, 256]               0
#           Linear-212                 [-1, 1000]         257,000
# ================================================================
# Total params: 37,209,024
# Trainable params: 37,209,024
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 379.37
# Params size (MB): 141.94
# Estimated Total Size (MB): 521.89
# ----------------------------------------------------------------
